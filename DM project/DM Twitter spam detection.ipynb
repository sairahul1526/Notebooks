# %%
print("Sai")
# Out:
# Sai

# %%
from scipy.io import arff
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv("95k-continuous.csv",names=['account_age','no_follower','no_following','no_userfavourites','no_lists','no_tweets','no_retweets','no_hashtag','no_usermentiom','no_urls','no_chars','no_digits','class'])
df
# Out:
#        account_age  no_follower  no_following  no_userfavourites  no_lists  \
# 0              242            0             0                  0         0
# 1              834            1             5                  0         0
# 2              978           44            18                  0         0
# 3              490            0            26                  0         0
# 4              248            0             0                  0         0
# 5              123            2           611                  0         0
# 6              303        13840           138                 78        13
# 7              206            0            14                  0         0
# 8              333            0             0                  0         0
# 9             1277            1            21                  5         0
# 10             804           35            29                  1         1
# 11             894           10            50                  5         0
# 12            1188            1           372                  0         0
# 13             921            5             6                  0         0
# 14            1040            0           222                  0         0
# 15            1191           45            52                 12         1
# 16             815            0             0                  0         0
# 17             944            2            61                  0         0
# 18             930            2            13                  0         0
# 19             972            0             0                  0         0
# 20            1132            0             0                  0         0
# 21            1409            2            45                  0         0
# 22             446            1             2                  0         0
# 23            1038            1            10                  0         0
# 24             720            4            25                 20         0
# 25            1359            0           252                  0         0
# 26             860            2             6                  1         0
# 27            1376           31           134                  1         0
# 28             765           17           573                 23         0
# 29             560            6            43                  0         0
# ...            ...          ...           ...                ...       ...
# 99970         1529         3099          3074                 17        64
# 99971         1552         4389            21                  0         9
# 99972          851          323           481                838         5
# 99973           15          376           729                  0         0
# 99974         1005          897          1849                 10         4
# 99975         1033          642           614                 25        29
# 99976         1089          197          1720                  3         1
# 99977          289         4852          4225                  0         9
# 99978         1169           40            94                  0         0
# 99979            9            3            53                  0         0
# 99980         1304        40851         44926                 13        52
# 99981          858            6             5                  0         0
# 99982          770          321          1532               1145         1
# 99983         1187            4           368                  0         0
# 99984          108          267           330                  0         0
# 99985          849        13125         13760                  1        29
# 99986           11           16           257                  0         0
# 99987          961            3             5                  0         0
# 99988          330            0             1                  0         0
# 99989          489           89            14                  0         1
# 99990         1884         1927          1438                  0       103
# 99991         1585           62           550                  2         0
# 99992          385           13           146                  1         0
# 99993         1311          257           205                 89         3
# 99994          535           34            31                  3         2
# 99995         1263         1027           122                  2         4
# 99996          349          371           184                 20         0
# 99997         1062          948           640                 95        91
# 99998          577          881           426                336        19
# 99999           71            3             9                  0         0
#
#        no_tweets  no_retweets  no_hashtag  no_usermentiom  no_urls  no_chars  \
# 0             62            0           1               0        1        29
# 1             64            0           1               0        1        22
# 2            114            0           1               0        1        35
# 3           3840            0           1               0        1        38
# 4             72            0           1               0        1        42
# 5            319            0           0               0        1        31
# 6           6352           24           0               1        1        79
# 7             65            0           1               0        1        30
# 8             63            0           1               0        1        26
# 9            125            0           1               0        1        24
# 10           237            0           1               0        1        27
# 11           215            0           1               0        1        23
# 12           454            0           0               0        1        68
# 13            62            0           1               0        1        20
# 14            63            0           1               0        1        20
# 15          4354            0           0               0        1        36
# 16            63            0           1               0        1        27
# 17            65            0           1               0        1        22
# 18            63            0           1               0        1        28
# 19            56            0           1               0        1        21
# 20            63            0           1               0        1        22
# 21            64            0           1               0        1        21
# 22            66            0           1               0        1        31
# 23          7100            0           1               0        1        31
# 24            67            0           1               0        1        20
# 25           331            0           0               0        1        40
# 26           109            0           1               0        1        27
# 27            68            0           1               0        1        26
# 28            72            0           1               0        1        23
# 29           333            0           0               0        1        38
# ...          ...          ...         ...             ...      ...       ...
# 99970     130248            0           0               0        1        45
# 99971       6153            0           0               0        1        32
# 99972     102237            1           0               1        1        34
# 99973        199            0           0               0        1        79
# 99974      65758            0           0               0        1        70
# 99975       4605            0           0               0        1       112
# 99976       7062            0           0               0        1        87
# 99977      68556            0           7               0        1       101
# 99978       9034            0           1               0        1       114
# 99979        588            0           0               0        1        48
# 99980      70949            0           0               0        1        10
# 99981        227            0           0               0        1        58
# 99982       1272            2           0               4        1        91
# 99983        598            0           0               0        1        41
# 99984       6580            0           0               0        1       110
# 99985     206534            0           0               0        1        12
# 99986       2208            0           0               0        1       114
# 99987         57            0           0               0        1        56
# 99988        375            0           0               0        1        61
# 99989       5233            0           0               0        1       120
# 99990       2112            0           0               0        1        62
# 99991       1876          672           1               1        1       118
# 99992        118            0           0               0        2        39
# 99993       3790            0           0               0        1        84
# 99994        280            0           0               0        1        31
# 99995      16148            0           1               0        1        99
# 99996       8001            0           0               0        2        87
# 99997       5793            0           0               1        1       104
# 99998      26722            0           0               0        1        84
# 99999       5499            0           0               0        1        66
#
#        no_digits  class
# 0              0      1
# 1              0      1
# 2              0      1
# 3              0      1
# 4              4      1
# 5              0      1
# 6              1      1
# 7              0      1
# 8              0      1
# 9              0      1
# 10             0      1
# 11             0      1
# 12             0      1
# 13             0      1
# 14             0      1
# 15             0      1
# 16             0      1
# 17             0      1
# 18             0      1
# 19             0      1
# 20             0      1
# 21             0      1
# 22             0      1
# 23             0      1
# 24             0      1
# 25             0      1
# 26             0      1
# 27             0      1
# 28             0      1
# 29             0      1
# ...          ...    ...
# 99970          0      0
# 99971          0      0
# 99972          0      0
# 99973          0      0
# 99974          8      0
# 99975          3      0
# 99976          1      0
# 99977          2      0
# 99978          0      0
# 99979          0      0
# 99980          0      0
# 99981          0      0
# 99982          0      0
# 99983          0      0
# 99984          5      0
# 99985          2      0
# 99986          0      0
# 99987          0      0
# 99988          3      0
# 99989          0      0
# 99990          0      0
# 99991          0      0
# 99992          0      0
# 99993          2      0
# 99994          0      0
# 99995          1      0
# 99996          8      0
# 99997          4      0
# 99998          0      0
# 99999          6      0
#
# [100000 rows x 13 columns]

# %%
df.describe()
# Out:
#          account_age   no_follower  no_following  no_userfavourites  \
# count  100000.000000  1.000000e+05  1.000000e+05      100000.000000
# mean      728.766140  3.985661e+03  1.130066e+03         885.817880
# std       539.999173  6.156881e+04  9.361515e+03        6552.960481
# min         0.000000 -1.000000e+00 -1.000000e+00          -1.000000
# 25%       256.000000  5.900000e+01  7.000000e+01           0.000000
# 50%       657.500000  2.570000e+02  2.400000e+02          12.000000
# 75%      1111.000000  8.230000e+02  6.700000e+02         188.000000
# max      2696.000000  5.314760e+06  1.561262e+06      507045.000000
#
#            no_lists     no_tweets    no_retweets     no_hashtag  \
# count  100000.00000  1.000000e+05  100000.000000  100000.000000
# mean       36.49020  2.309988e+04     117.052280       0.490910
# std       639.78925  5.726457e+04    1592.459468       1.226569
# min         0.00000 -1.000000e+00       0.000000       0.000000
# 25%         0.00000  1.131000e+03       0.000000       0.000000
# 50%         1.00000  5.872000e+03       0.000000       0.000000
# 75%         5.00000  2.095200e+04       0.000000       1.000000
# max     78020.00000  2.886206e+06  112088.000000      16.000000
#
#        no_usermentiom       no_urls       no_chars      no_digits  \
# count   100000.000000  100000.00000  100000.000000  100000.000000
# mean         0.380020       1.05183      65.071630       1.457350
# std          0.697459       0.40108      32.181068       2.846426
# min          0.000000       1.00000       0.000000       0.000000
# 25%          0.000000       1.00000      39.000000       0.000000
# 50%          0.000000       1.00000      64.000000       0.000000
# 75%          1.000000       1.00000      92.000000       2.000000
# max         10.000000       6.00000     160.000000      92.000000
#
#                class
# count  100000.000000
# mean        0.050000
# std         0.217946
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 13 columns):
# account_age          100000 non-null int64
# no_follower          100000 non-null int64
# no_following         100000 non-null int64
# no_userfavourites    100000 non-null int64
# no_lists             100000 non-null int64
# no_tweets            100000 non-null int64
# no_retweets          100000 non-null int64
# no_hashtag           100000 non-null int64
# no_usermentiom       100000 non-null int64
# no_urls              100000 non-null int64
# no_chars             100000 non-null int64
# no_digits            100000 non-null int64
# class                100000 non-null int64
# dtypes: int64(13)
# memory usage: 9.9 MB

# %%
df.columns
# Out:
# Index(['account_age', 'no_follower', 'no_following', 'no_userfavourites',
#        'no_lists', 'no_tweets', 'no_retweets', 'no_hashtag', 'no_usermentiom',
#        'no_urls', 'no_chars', 'no_digits', 'class'],
#       dtype='object')

# %%
df.groupby('class')['class'].value_counts()
# Out:
# class  class
# 0      0        95000
# 1      1         5000
# Name: class, dtype: int64

# %%
df['class'] = df['class'].astype('category').cat.codes

# %%
df.groupby('class')['class'].value_counts()
# Out:
# class  class
# 0      0        95000
# 1      1         5000
# Name: class, dtype: int64

# %% [markdown]
# 0 - non-spam

# %% [markdown]
# 1 - spam

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report,confusion_matrix
#from imblearn.under_sampling import RandomUnderSampler

# %% [markdown]
# # Fig. 1. Performance degradation caused by class imbalance

# %%
fig1 = []

for i in range(2, 21, 2):
#     for every alpha(class imbalance rate), applied random forest for 10 times
    for j in range(10):
        sample = df[df['class'] == 1].sample(1000,replace=True)
    #         took 1000 as base and multiplied by alpha(class imbalance rate)
        sample = sample.append(df[df['class'] == 0].sample(1000*i,replace=True), ignore_index=True)

        X = sample.drop('class',axis=1)
        y = sample['class']

        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.50)

        rfc = RandomForestClassifier()
        rfc.fit(X_train, y_train)
        rfc_pred = rfc.predict(X_test)

        matrix = confusion_matrix(y_test,rfc_pred)
    #         [TPR, FPR,precision, f-Measure,class imbalance rate]
        fig1.append([matrix[1][1]/float(matrix[1][1] + matrix[1][0]), matrix[0][1]/float(matrix[0][1] + matrix[0][0]),matrix[1][1]/float(matrix[1][1] + matrix[0][1]),2*matrix[1][1]/float(2*matrix[1][1] + matrix[0][1]+matrix[1][0]), i,"Class_Imbalance_Rate"])

# %%
fig1 = pd.DataFrame(fig1)
fig1.head()
# Out:
#           0         1         2         3  4                     5
# 0  0.860082  0.012821  0.969838  0.911668  2  Class_Imbalance_Rate
# 1  0.820202  0.011940  0.971292  0.889376  2  Class_Imbalance_Rate
# 2  0.838835  0.020305  0.955752  0.893485  2  Class_Imbalance_Rate
# 3  0.902637  0.027805  0.940803  0.921325  2  Class_Imbalance_Rate
# 4  0.871595  0.017241  0.963441  0.915220  2  Class_Imbalance_Rate

# %%
sns.boxplot(fig1[4], fig1[0])
plt.xlabel("Class Imabalance Rate")
plt.ylabel("True Positive Rate")
# Out:
# Text(0,0.5,'True Positive Rate')

# %%
sns.boxplot(fig1[4], fig1[1])
plt.xlabel("Class Imabalance Rate")
plt.ylabel("False Positive Rate")
# Out:
# Text(0,0.5,'False Positive Rate')

# %%
import math
import functools

# %%
def ROS(Dplus, alpha):
    return Dplus.append(Dplus.sample(math.ceil(alpha*len(Dplus)), replace=True), ignore_index=True)

# %%
len(df)
# Out:
# 100000

# %%
len(ROS(df, 1.4))
# Out:
# 240000

# %%
def RUS(Dminus, beta):
    return Dminus.sample(math.ceil((1-beta)*len(Dminus)))

# %%
len(RUS(df, 0.8))
# Out:
# 20000

# %%
import copy
Dplus = df[df['class'] == 1].sample(4000)
deep_Dplus=copy.deepcopy(Dplus)
#deep_dplus.sort_values('no_following',axis=0)
deep_Dplus.mean(axis=0)
# Out:
# account_age           800.87525
# no_follower           526.33025
# no_following          393.19500
# no_userfavourites     228.03600
# no_lists                1.66975
# no_tweets            6328.53125
# no_retweets             4.96800
# no_hashtag              0.83175
# no_usermentiom          0.04350
# no_urls                 1.01600
# no_chars               43.04700
# no_digits               1.19650
# class                   1.00000
# dtype: float64

# %%
attributes = {1:'account_age',2:'no_follower',3:'no_following',4:'no_userfavourites',5:'no_lists',6:'no_tweets',7:'no_retweets',8:'no_hashtag',9:'no_usermentiom',10:'no_urls',11:'no_chars',12:'no_digits'}

# %%
def bin(ar,d,interval_size,s,length):
    if s*interval_size -1 > length:
        width=ar[length-1,d-1]-ar[(s-1)*interval_size,d-1]
        centre = ar[int((length-1 + (s-1)*interval_size)/2)][d-1]
    else:
        width = ar[(s)*interval_size-1,d-1]-ar[(s-1)*interval_size,d-1] 
        centre = ar[int((s*interval_size-1+(s-1)*interval_size-1)/2),d-1]
    
    return centre,width

# %%
def weight_assign(ar,centre,width,d,length):
    if width==0:
        weights_array=np.ones((length,))
    else:
        a= ar[:,d-1]
        b = abs(a-centre)
        c= b<=width
        b[c]  = 1 - b[c]/width
        d=np.invert(c)
        b[d] = 0
        weights_array = b
    return weights_array

# %%
my_list=[]

# %%
my_list = [1]

my_list.append(0)
my_list.append(3) 
weights_array = np.array(my_list)
print (weights_array)
# Out:
# [1 0 3]

# %%
def get_info(arr):
    return arr.sum()

# %%
def weighted_mean(arr,ar,t,length):
    arr = np.atleast_2d(arr)
    arr=arr.reshape(length,1)
    b = arr*ar
    c = b.sum(axis=0)
    c[t-1]=1
    return c

# %%
def FOS(deep_Dplus,Dplus, alpha):
    length=len(deep_Dplus)
    t=int(length*alpha/12)
    interval_size=int(length/t)
    ar = deep_Dplus.as_matrix()
    for d in range(1,13):
        deep_Dplus.sort_values(attributes[d],axis=0)
        for s in range(1,t+1):
            centre,width = bin(ar,d,interval_size,s,length)
            
            
            arr = weight_assign(ar,centre,width,d,length)
            
            if get_info(arr) == 0:
                #Dplus.append(deep_Dplus.mean(axis=0),ignore_index=True)
                df2=pd.DataFrame(np.atleast_2d(deep_Dplus.mean(axis=0)),columns=['account_age','no_follower','no_following','no_userfavourites','no_lists','no_tweets','no_retweets','no_hashtag','no_usermentiom','no_urls','no_chars','no_digits','class'])
                frames=[Dplus,df2]
                Dplus=pd.concat(frames)
            else:
                df2=pd.DataFrame(np.atleast_2d(weighted_mean(arr,ar,13,length)),columns=['account_age','no_follower','no_following','no_userfavourites','no_lists','no_tweets','no_retweets','no_hashtag','no_usermentiom','no_urls','no_chars','no_digits','class'])
#                print ("hie")
                frames=[Dplus,df2]
                Dplus=pd.concat(frames)
#                Dplus.append(df2,ignore_index=True)
    
    return Dplus

# %%
df2=pd.DataFrame(np.atleast_2d([0,1,4]),columns=['account_age','no_follower','f'])
df1=pd.DataFrame(np.atleast_2d([2,7,8]),columns=['account_age','no_follower','f'])
df3=pd.DataFrame(np.atleast_2d([3,8,9]),columns=['account_age','no_follower','f'])
frames=[df1,df2]
#result=
df1=pd.concat(frames)
df1

frames=[df1,df1]
df1=pd.concat(frames)
df1
dp = df2.append(df3,ignore_index=True)
dp
df2
#frames=[result,df3]
#result=pd.concat(frames)
#result
# Out:
#    account_age  no_follower  f
# 0            0            1  4

# %%
fig2 = []
i=2
for i in range(2,21,2):
    Target = df['class']

    Train, Test, Target_train, Target_test = train_test_split(df ,Target, test_size=0.50)
    Test_common = Test.drop('class',axis=1)
    for j in range(10):
        #     for every alpha(class imbalance rate), applied random forest for 10 times
        print(str(i)+":")
        print(j)
        #         taking 1k spam and 1k *i non-spam, then ROS is valid for class imbalance rate 20(no need to add samples as 80k/4k = 20)
        dplus = Train[Train['class'] == 1].sample(1000,replace='True') # spam
        dminus = Train[Train['class'] == 0].sample(1000*i,replace='True') # non-spam


        #         Random over sampling
        sample_ROS = dminus.append(ROS(dplus,i-1) , ignore_index=True)
        X_ROS = sample_ROS.drop('class',axis=1)
        y_ROS = sample_ROS['class']

        print(y_ROS.value_counts())

        #X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.50)


        rfc_ROS = RandomForestClassifier()
        rfc_ROS.fit(X_ROS, y_ROS)
        rfc_ROS_pred = rfc_ROS.predict(Test_common)

        matrix = confusion_matrix(Target_test,rfc_ROS_pred)
        #         [TPR, FPR, precision, class imbalance rate]
        fig2.append([matrix[1][1]/float(matrix[1][1] + matrix[1][0]), matrix[0][1]/float(matrix[0][1] + matrix[0][0]), matrix[1][1]/float(matrix[1][1] + matrix[0][1]),2*matrix[1][1]/float(2*matrix[1][1] + matrix[0][1]+matrix[1][0]),i, "ROS"])


        #         Random under sampling_standalone
        sample_RUS = dplus.append(RUS(dminus,.3) , ignore_index=True)
        X_RUS = sample_RUS.drop('class',axis=1)
        y_RUS = sample_RUS['class']

        print(y_RUS.value_counts())

        #X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.50)

        rfc_RUS = RandomForestClassifier()
        rfc_RUS.fit(X_RUS, y_RUS)
        rfc_RUS_pred = rfc_RUS.predict(Test_common)

        matrix = confusion_matrix(Target_test,rfc_RUS_pred)
        #         [TPR, FPR, precision, class imbalance rate]
        fig2.append([matrix[1][1]/float(matrix[1][1] + matrix[1][0]), matrix[0][1]/float(matrix[0][1] + matrix[0][0]), matrix[1][1]/float(matrix[1][1] + matrix[0][1]),2*matrix[1][1]/float(2*matrix[1][1] + matrix[0][1]+matrix[1][0]), i, "RUS"])

        #         Random under sampling_ensembler
        sample_RUS = dplus.append(RUS(dminus,1-1/i) , ignore_index=True)
        X_RUS = sample_RUS.drop('class',axis=1)
        y_RUS = sample_RUS['class']

        #X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.50)

        rfc_RUS = RandomForestClassifier()
        rfc_RUS.fit(X_RUS, y_RUS)
        rfc_RUS_pred = rfc_RUS.predict(Test_common)
        #       Fuzzy based over sampling
        deep_Dplus=copy.deepcopy(dplus)
        sample_FOS = dminus.append(FOS(deep_Dplus,dplus,i-1),ignore_index =True)
        X_FOS = sample_FOS.drop('class',axis=1)
        y_FOS = sample_FOS['class']

        print(y_FOS.value_counts())
       # X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.50)

        rfc_FOS = RandomForestClassifier()
        rfc_FOS.fit(X_FOS, y_FOS)
        rfc_FOS_pred = rfc_FOS.predict(Test_common)

        matrix = confusion_matrix(Target_test,rfc_FOS_pred)
        #        [TPR, FPR, precision, class imbalance rate]
        fig2.append([matrix[1][1]/float(matrix[1][1] + matrix[1][0]), matrix[0][1]/float(matrix[0][1] + matrix[0][0]), matrix[1][1]/float(matrix[1][1] + matrix[0][1]),2*matrix[1][1]/float(2*matrix[1][1] + matrix[0][1]+matrix[1][0]),i, "FOS"])

        w = np.zeros((len(Test),))

        z = rfc_ROS_pred == 1
        y = rfc_RUS_pred == 1
        x = rfc_FOS_pred == 1
        w[z]= w[z]+1
        w[y]=w[y]+1
        w[x]=w[x]+1
        p = np.invert(z)
        q = np.invert(y)
        r = np.invert(x)
        w[p]= w[p]-1
        w[q]=w[q]-1
        w[r]=w[r]-1

        ensembler_predict = np.zeros((len(Test),))
        u = w>0
        ensembler_predict[u]=1


        matrix = confusion_matrix(Target_test,ensembler_predict)
        fig2.append([matrix[1][1]/float(matrix[1][1] + matrix[1][0]), matrix[0][1]/float(matrix[0][1] + matrix[0][0]), matrix[1][1]/float(matrix[1][1] + matrix[0][1]),2*matrix[1][1]/float(2*matrix[1][1] + matrix[0][1]+matrix[1][0]),i, "ensemble"])
# Out:
# 2:
# 0
# 1    2000
# 0    2000
# Name: class, dtype: int64
# 0    1400
# 1    1000
# Name: class, dtype: int64
# 0.0    2000
# 1.0    1996
# Name: class, dtype: int64
# 2:
# 1
# 1    2000
# 0    2000
# Name: class, dtype: int64
# 0    1400
# 1    1000
# Name: class, dtype: int64
# 0.0    2000
# 1.0    1996
# Name: class, dtype: int64
# 2:
# 2
# 1    2000
# 0    2000
# Name: class, dtype: int64
# 0    1400
# 1    1000
# Name: class, dtype: int64
# 0.0    2000
# 1.0    1996
# Name: class, dtype: int64
# 2:
# 3
# 1    2000
# 0    2000
# Name: class, dtype: int64
# 0    1400
# 1    1000
# Name: class, dtype: int64
# 0.0    2000
# 1.0    1996
# Name: class, dtype: int64
# 2:
# 4
# 1    2000
# 0    2000
# Name: class, dtype: int64
# 0    1400
# 1    1000
# Name: class, dtype: int64
# 0.0    2000
# 1.0    1996
# Name: class, dtype: int64
# 2:
# 5
# 1    2000
# 0    2000
# Name: class, dtype: int64
# 0    1400
# 1    1000
# Name: class, dtype: int64
# 0.0    2000
# 1.0    1996
# Name: class, dtype: int64
# 2:
# 6
# 1    2000
# 0    2000
# Name: class, dtype: int64
# 0    1400
# 1    1000
# Name: class, dtype: int64
# 0.0    2000
# 1.0    1996
# Name: class, dtype: int64
# 2:
# 7
# 1    2000
# 0    2000
# Name: class, dtype: int64
# 0    1400
# 1    1000
# Name: class, dtype: int64
# 0.0    2000
# 1.0    1996
# Name: class, dtype: int64
# 2:
# 8
# 1    2000
# 0    2000
# Name: class, dtype: int64
# 0    1400
# 1    1000
# Name: class, dtype: int64
# 0.0    2000
# 1.0    1996
# Name: class, dtype: int64
# 2:
# 9
# 1    2000
# 0    2000
# Name: class, dtype: int64
# 0    1400
# 1    1000
# Name: class, dtype: int64
# 0.0    2000
# 1.0    1996
# Name: class, dtype: int64
# 4:
# 0
# 1    4000
# 0    4000
# Name: class, dtype: int64
# 0    2800
# 1    1000
# Name: class, dtype: int64
# 1.0    4000
# 0.0    4000
# Name: class, dtype: int64
# 4:
# 1
# 1    4000
# 0    4000
# Name: class, dtype: int64
# 0    2800
# 1    1000
# Name: class, dtype: int64
# 1.0    4000
# 0.0    4000
# Name: class, dtype: int64
# 4:
# 2
# 1    4000
# 0    4000
# Name: class, dtype: int64
# 0    2800
# 1    1000
# Name: class, dtype: int64
# 1.0    4000
# 0.0    4000
# Name: class, dtype: int64
# 4:
# 3
# 1    4000
# 0    4000
# Name: class, dtype: int64
# 0    2800
# 1    1000
# Name: class, dtype: int64
# 1.0    4000
# 0.0    4000
# Name: class, dtype: int64
# 4:
# 4
# 1    4000
# 0    4000
# Name: class, dtype: int64
# 0    2800
# 1    1000
# Name: class, dtype: int64
# 1.0    4000
# 0.0    4000
# Name: class, dtype: int64
# 4:
# 5
# 1    4000
# 0    4000
# Name: class, dtype: int64
# 0    2800
# 1    1000
# Name: class, dtype: int64
# 1.0    4000
# 0.0    4000
# Name: class, dtype: int64
# 4:
# 6
# 1    4000
# 0    4000
# Name: class, dtype: int64
# 0    2800
# 1    1000
# Name: class, dtype: int64
# 1.0    4000
# 0.0    4000
# Name: class, dtype: int64
# 4:
# 7
# 1    4000
# 0    4000
# Name: class, dtype: int64
# 0    2800
# 1    1000
# Name: class, dtype: int64
# 1.0    4000
# 0.0    4000
# Name: class, dtype: int64
# 4:
# 8
# 1    4000
# 0    4000
# Name: class, dtype: int64
# 0    2800
# 1    1000
# Name: class, dtype: int64
# 1.0    4000
# 0.0    4000
# Name: class, dtype: int64
# 4:
# 9
# 1    4000
# 0    4000
# Name: class, dtype: int64
# 0    2800
# 1    1000
# Name: class, dtype: int64
# 1.0    4000
# 0.0    4000
# Name: class, dtype: int64
# 6:
# 0
# 1    6000
# 0    6000
# Name: class, dtype: int64
# 0    4200
# 1    1000
# Name: class, dtype: int64
# 0.0    6000
# 1.0    5992
# Name: class, dtype: int64
# 6:
# 1
# 1    6000
# 0    6000
# Name: class, dtype: int64
# 0    4200
# 1    1000
# Name: class, dtype: int64
# 0.0    6000
# 1.0    5992
# Name: class, dtype: int64
# 6:
# 2
# 1    6000
# 0    6000
# Name: class, dtype: int64
# 0    4200
# 1    1000
# Name: class, dtype: int64
# 0.0    6000
# 1.0    5992
# Name: class, dtype: int64
# 6:
# 3
# 1    6000
# 0    6000
# Name: class, dtype: int64
# 0    4200
# 1    1000
# Name: class, dtype: int64
# 0.0    6000
# 1.0    5992
# Name: class, dtype: int64
# 6:
# 4
# 1    6000
# 0    6000
# Name: class, dtype: int64
# 0    4200
# 1    1000
# Name: class, dtype: int64
# 0.0    6000
# 1.0    5992
# Name: class, dtype: int64
# 6:
# 5
# 1    6000
# 0    6000
# Name: class, dtype: int64
# 0    4200
# 1    1000
# Name: class, dtype: int64
# 0.0    6000
# 1.0    5992
# Name: class, dtype: int64
# 6:
# 6
# 1    6000
# 0    6000
# Name: class, dtype: int64
# 0    4200
# 1    1000
# Name: class, dtype: int64
# 0.0    6000
# 1.0    5992
# Name: class, dtype: int64
# 6:
# 7
# 1    6000
# 0    6000
# Name: class, dtype: int64
# 0    4200
# 1    1000
# Name: class, dtype: int64
# 0.0    6000
# 1.0    5992
# Name: class, dtype: int64
# 6:
# 8
# 1    6000
# 0    6000
# Name: class, dtype: int64
# 0    4200
# 1    1000
# Name: class, dtype: int64
# 0.0    6000
# 1.0    5992
# Name: class, dtype: int64
# 6:
# 9
# 1    6000
# 0    6000
# Name: class, dtype: int64
# 0    4200
# 1    1000
# Name: class, dtype: int64
# 0.0    6000
# 1.0    5992
# Name: class, dtype: int64
# 8:
# 0
# 1    8000
# 0    8000
# Name: class, dtype: int64
# 0    5600
# 1    1000
# Name: class, dtype: int64
# 0.0    8000
# 1.0    7996
# Name: class, dtype: int64
# 8:
# 1
# 1    8000
# 0    8000
# Name: class, dtype: int64
# 0    5600
# 1    1000
# Name: class, dtype: int64
# 0.0    8000
# 1.0    7996
# Name: class, dtype: int64
# 8:
# 2
# 1    8000
# 0    8000
# Name: class, dtype: int64
# 0    5600
# 1    1000
# Name: class, dtype: int64
# 0.0    8000
# 1.0    7996
# Name: class, dtype: int64
# 8:
# 3
# 1    8000
# 0    8000
# Name: class, dtype: int64
# 0    5600
# 1    1000
# Name: class, dtype: int64
# 0.0    8000
# 1.0    7996
# Name: class, dtype: int64
# 8:
# 4
# 1    8000
# 0    8000
# Name: class, dtype: int64
# 0    5600
# 1    1000
# Name: class, dtype: int64
# 0.0    8000
# 1.0    7996
# Name: class, dtype: int64
# 8:
# 5
# 1    8000
# 0    8000
# Name: class, dtype: int64
# 0    5600
# 1    1000
# Name: class, dtype: int64
# 0.0    8000
# 1.0    7996
# Name: class, dtype: int64
# 8:
# 6
# 1    8000
# 0    8000
# Name: class, dtype: int64
# 0    5600
# 1    1000
# Name: class, dtype: int64
# 0.0    8000
# 1.0    7996
# Name: class, dtype: int64
# 8:
# 7
# 1    8000
# 0    8000
# Name: class, dtype: int64
# 0    5600
# 1    1000
# Name: class, dtype: int64
# 0.0    8000
# 1.0    7996
# Name: class, dtype: int64
# 8:
# 8
# 1    8000
# 0    8000
# Name: class, dtype: int64
# 0    5600
# 1    1000
# Name: class, dtype: int64
# 0.0    8000
# 1.0    7996
# Name: class, dtype: int64
# 8:
# 9
# 1    8000
# 0    8000
# Name: class, dtype: int64
# 0    5600
# 1    1000
# Name: class, dtype: int64
# 0.0    8000
# 1.0    7996
# Name: class, dtype: int64
# 10:
# 0
# 1    10000
# 0    10000
# Name: class, dtype: int64
# 0    7000
# 1    1000
# Name: class, dtype: int64
# 1.0    10000
# 0.0    10000
# Name: class, dtype: int64
# 10:
# 1
# 1    10000
# 0    10000
# Name: class, dtype: int64
# 0    7000
# 1    1000
# Name: class, dtype: int64
# 1.0    10000
# 0.0    10000
# Name: class, dtype: int64
# 10:
# 2
# 1    10000
# 0    10000
# Name: class, dtype: int64
# 0    7000
# 1    1000
# Name: class, dtype: int64
# 1.0    10000
# 0.0    10000
# Name: class, dtype: int64
# 10:
# 3
# 1    10000
# 0    10000
# Name: class, dtype: int64
# 0    7000
# 1    1000
# Name: class, dtype: int64
# 1.0    10000
# 0.0    10000
# Name: class, dtype: int64
# 10:
# 4
# 1    10000
# 0    10000
# Name: class, dtype: int64
# 0    7000
# 1    1000
# Name: class, dtype: int64
# 1.0    10000
# 0.0    10000
# Name: class, dtype: int64
# 10:
# 5
# 1    10000
# 0    10000
# Name: class, dtype: int64
# 0    7000
# 1    1000
# Name: class, dtype: int64
# 1.0    10000
# 0.0    10000
# Name: class, dtype: int64
# 10:
# 6
# 1    10000
# 0    10000
# Name: class, dtype: int64
# 0    7000
# 1    1000
# Name: class, dtype: int64
# 1.0    10000
# 0.0    10000
# Name: class, dtype: int64
# 10:
# 7
# 1    10000
# 0    10000
# Name: class, dtype: int64
# 0    7000
# 1    1000
# Name: class, dtype: int64
# 1.0    10000
# 0.0    10000
# Name: class, dtype: int64
# 10:
# 8
# 1    10000
# 0    10000
# Name: class, dtype: int64
# 0    7000
# 1    1000
# Name: class, dtype: int64
# 1.0    10000
# 0.0    10000
# Name: class, dtype: int64
# 10:
# 9
# 1    10000
# 0    10000
# Name: class, dtype: int64
# 0    7000
# 1    1000
# Name: class, dtype: int64
# 1.0    10000
# 0.0    10000
# Name: class, dtype: int64
# 12:
# 0
# 1    12000
# 0    12000
# Name: class, dtype: int64
# 0    8400
# 1    1000
# Name: class, dtype: int64
# 0.0    12000
# 1.0    11992
# Name: class, dtype: int64
# 12:
# 1
# 1    12000
# 0    12000
# Name: class, dtype: int64
# 0    8400
# 1    1000
# Name: class, dtype: int64
# 0.0    12000
# 1.0    11992
# Name: class, dtype: int64
# 12:
# 2
# 1    12000
# 0    12000
# Name: class, dtype: int64
# 0    8400
# 1    1000
# Name: class, dtype: int64
# 0.0    12000
# 1.0    11992
# Name: class, dtype: int64
# 12:
# 3
# 1    12000
# 0    12000
# Name: class, dtype: int64
# 0    8400
# 1    1000
# Name: class, dtype: int64
# 0.0    12000
# 1.0    11992
# Name: class, dtype: int64
# 12:
# 4
# 1    12000
# 0    12000
# Name: class, dtype: int64
# 0    8400
# 1    1000
# Name: class, dtype: int64
# 0.0    12000
# 1.0    11992
# Name: class, dtype: int64
# 12:
# 5
# 1    12000
# 0    12000
# Name: class, dtype: int64
# 0    8400
# 1    1000
# Name: class, dtype: int64
# 0.0    12000
# 1.0    11992
# Name: class, dtype: int64
# 12:
# 6
# 1    12000
# 0    12000
# Name: class, dtype: int64
# 0    8400
# 1    1000
# Name: class, dtype: int64
# 0.0    12000
# 1.0    11992
# Name: class, dtype: int64
# 12:
# 7
# 1    12000
# 0    12000
# Name: class, dtype: int64
# 0    8400
# 1    1000
# Name: class, dtype: int64
# 0.0    12000
# 1.0    11992
# Name: class, dtype: int64
# 12:
# 8
# 1    12000
# 0    12000
# Name: class, dtype: int64
# 0    8400
# 1    1000
# Name: class, dtype: int64
# 0.0    12000
# 1.0    11992
# Name: class, dtype: int64
# 12:
# 9
# 1    12000
# 0    12000
# Name: class, dtype: int64
# 0    8400
# 1    1000
# Name: class, dtype: int64
# 0.0    12000
# 1.0    11992
# Name: class, dtype: int64
# 14:
# 0
# 1    14000
# 0    14000
# Name: class, dtype: int64
# 0    9800
# 1    1000
# Name: class, dtype: int64
# 0.0    14000
# 1.0    13996
# Name: class, dtype: int64
# 14:
# 1
# 1    14000
# 0    14000
# Name: class, dtype: int64
# 0    9800
# 1    1000
# Name: class, dtype: int64
# 0.0    14000
# 1.0    13996
# Name: class, dtype: int64
# 14:
# 2
# 1    14000
# 0    14000
# Name: class, dtype: int64
# 0    9800
# 1    1000
# Name: class, dtype: int64
# 0.0    14000
# 1.0    13996
# Name: class, dtype: int64
# 14:
# 3
# 1    14000
# 0    14000
# Name: class, dtype: int64
# 0    9800
# 1    1000
# Name: class, dtype: int64
# 0.0    14000
# 1.0    13996
# Name: class, dtype: int64
# 14:
# 4
# 1    14000
# 0    14000
# Name: class, dtype: int64
# 0    9800
# 1    1000
# Name: class, dtype: int64
# 0.0    14000
# 1.0    13996
# Name: class, dtype: int64
# 14:
# 5
# 1    14000
# 0    14000
# Name: class, dtype: int64
# 0    9800
# 1    1000
# Name: class, dtype: int64
# 0.0    14000
# 1.0    13996
# Name: class, dtype: int64
# 14:
# 6
# 1    14000
# 0    14000
# Name: class, dtype: int64
# 0    9800
# 1    1000
# Name: class, dtype: int64
# 0.0    14000
# 1.0    13996
# Name: class, dtype: int64
# 14:
# 7
# 1    14000
# 0    14000
# Name: class, dtype: int64
# 0    9800
# 1    1000
# Name: class, dtype: int64
# 0.0    14000
# 1.0    13996
# Name: class, dtype: int64
# 14:
# 8
# 1    14000
# 0    14000
# Name: class, dtype: int64
# 0    9800
# 1    1000
# Name: class, dtype: int64
# 0.0    14000
# 1.0    13996
# Name: class, dtype: int64
# 14:
# 9
# 1    14000
# 0    14000
# Name: class, dtype: int64
# 0    9800
# 1    1000
# Name: class, dtype: int64
# 0.0    14000
# 1.0    13996
# Name: class, dtype: int64
# 16:
# 0
# 1    16000
# 0    16000
# Name: class, dtype: int64
# 0    11200
# 1     1000
# Name: class, dtype: int64
# 1.0    16000
# 0.0    16000
# Name: class, dtype: int64
# 16:
# 1
# 1    16000
# 0    16000
# Name: class, dtype: int64
# 0    11200
# 1     1000
# Name: class, dtype: int64
# 1.0    16000
# 0.0    16000
# Name: class, dtype: int64
# 16:
# 2
# 1    16000
# 0    16000
# Name: class, dtype: int64
# 0    11200
# 1     1000
# Name: class, dtype: int64
# 1.0    16000
# 0.0    16000
# Name: class, dtype: int64
# 16:
# 3
# 1    16000
# 0    16000
# Name: class, dtype: int64
# 0    11200
# 1     1000
# Name: class, dtype: int64
# 1.0    16000
# 0.0    16000
# Name: class, dtype: int64
# 16:
# 4
# 1    16000
# 0    16000
# Name: class, dtype: int64
# 0    11200
# 1     1000
# Name: class, dtype: int64
# 1.0    16000
# 0.0    16000
# Name: class, dtype: int64
# 16:
# 5
# 1    16000
# 0    16000
# Name: class, dtype: int64
# 0    11200
# 1     1000
# Name: class, dtype: int64
# 1.0    16000
# 0.0    16000
# Name: class, dtype: int64
# 16:
# 6
# 1    16000
# 0    16000
# Name: class, dtype: int64
# 0    11200
# 1     1000
# Name: class, dtype: int64
# 1.0    16000
# 0.0    16000
# Name: class, dtype: int64
# 16:
# 7
# 1    16000
# 0    16000
# Name: class, dtype: int64
# 0    11200
# 1     1000
# Name: class, dtype: int64
# 1.0    16000
# 0.0    16000
# Name: class, dtype: int64
# 16:
# 8
# 1    16000
# 0    16000
# Name: class, dtype: int64
# 0    11200
# 1     1000
# Name: class, dtype: int64
# 1.0    16000
# 0.0    16000
# Name: class, dtype: int64
# 16:
# 9
# 1    16000
# 0    16000
# Name: class, dtype: int64
# 0    11200
# 1     1000
# Name: class, dtype: int64
# 1.0    16000
# 0.0    16000
# Name: class, dtype: int64
# 18:
# 0
# 1    18000
# 0    18000
# Name: class, dtype: int64
# 0    12600
# 1     1000
# Name: class, dtype: int64
# 0.0    18000
# 1.0    17992
# Name: class, dtype: int64
# 18:
# 1
# 1    18000
# 0    18000
# Name: class, dtype: int64
# 0    12600
# 1     1000
# Name: class, dtype: int64
# 0.0    18000
# 1.0    17992
# Name: class, dtype: int64
# 18:
# 2
# 1    18000
# 0    18000
# Name: class, dtype: int64
# 0    12600
# 1     1000
# Name: class, dtype: int64
# 0.0    18000
# 1.0    17992
# Name: class, dtype: int64
# 18:
# 3
# 1    18000
# 0    18000
# Name: class, dtype: int64
# 0    12600
# 1     1000
# Name: class, dtype: int64
# 0.0    18000
# 1.0    17992
# Name: class, dtype: int64
# 18:
# 4
# 1    18000
# 0    18000
# Name: class, dtype: int64
# 0    12600
# 1     1000
# Name: class, dtype: int64
# 0.0    18000
# 1.0    17992
# Name: class, dtype: int64
# 18:
# 5
# 1    18000
# 0    18000
# Name: class, dtype: int64
# 0    12600
# 1     1000
# Name: class, dtype: int64
# 0.0    18000
# 1.0    17992
# Name: class, dtype: int64
# 18:
# 6
# 1    18000
# 0    18000
# Name: class, dtype: int64
# 0    12600
# 1     1000
# Name: class, dtype: int64
# 0.0    18000
# 1.0    17992
# Name: class, dtype: int64
# 18:
# 7
# 1    18000
# 0    18000
# Name: class, dtype: int64
# 0    12600
# 1     1000
# Name: class, dtype: int64
# 0.0    18000
# 1.0    17992
# Name: class, dtype: int64
# 18:
# 8
# 1    18000
# 0    18000
# Name: class, dtype: int64
# 0    12600
# 1     1000
# Name: class, dtype: int64
# 0.0    18000
# 1.0    17992
# Name: class, dtype: int64
# 18:
# 9
# 1    18000
# 0    18000
# Name: class, dtype: int64
# 0    12600
# 1     1000
# Name: class, dtype: int64
# 0.0    18000
# 1.0    17992
# Name: class, dtype: int64
# 20:
# 0
# 1    20000
# 0    20000
# Name: class, dtype: int64
# 0    14000
# 1     1000
# Name: class, dtype: int64
# 0.0    20000
# 1.0    19996
# Name: class, dtype: int64
# 20:
# 1
# 1    20000
# 0    20000
# Name: class, dtype: int64
# 0    14000
# 1     1000
# Name: class, dtype: int64
# 0.0    20000
# 1.0    19996
# Name: class, dtype: int64
# 20:
# 2
# 1    20000
# 0    20000
# Name: class, dtype: int64
# 0    14000
# 1     1000
# Name: class, dtype: int64
# 0.0    20000
# 1.0    19996
# Name: class, dtype: int64
# 20:
# 3
# 1    20000
# 0    20000
# Name: class, dtype: int64
# 0    14000
# 1     1000
# Name: class, dtype: int64
# 0.0    20000
# 1.0    19996
# Name: class, dtype: int64
# 20:
# 4
# 1    20000
# 0    20000
# Name: class, dtype: int64
# 0    14000
# 1     1000
# Name: class, dtype: int64
# 0.0    20000
# 1.0    19996
# Name: class, dtype: int64
# 20:
# 5
# 1    20000
# 0    20000
# Name: class, dtype: int64
# 0    14000
# 1     1000
# Name: class, dtype: int64
# 0.0    20000
# 1.0    19996
# Name: class, dtype: int64
# 20:
# 6
# 1    20000
# 0    20000
# Name: class, dtype: int64
# 0    14000
# 1     1000
# Name: class, dtype: int64
# 0.0    20000
# 1.0    19996
# Name: class, dtype: int64
# 20:
# 7
# 1    20000
# 0    20000
# Name: class, dtype: int64
# 0    14000
# 1     1000
# Name: class, dtype: int64
# 0.0    20000
# 1.0    19996
# Name: class, dtype: int64
# 20:
# 8
# 1    20000
# 0    20000
# Name: class, dtype: int64
# 0    14000
# 1     1000
# Name: class, dtype: int64
# 0.0    20000
# 1.0    19996
# Name: class, dtype: int64
# 20:
# 9
# 1    20000
# 0    20000
# Name: class, dtype: int64
# 0    14000
# 1     1000
# Name: class, dtype: int64
# 0.0    20000
# 1.0    19996
# Name: class, dtype: int64

# %%
fig3 = pd.DataFrame(fig2)
fig1 = fig1.append(fig3)
fig1
# Out:
#             0         1         2         3   4                     5
# 0    0.860082  0.012821  0.969838  0.911668   2  Class_Imbalance_Rate
# 1    0.820202  0.011940  0.971292  0.889376   2  Class_Imbalance_Rate
# 2    0.838835  0.020305  0.955752  0.893485   2  Class_Imbalance_Rate
# 3    0.902637  0.027805  0.940803  0.921325   2  Class_Imbalance_Rate
# 4    0.871595  0.017241  0.963441  0.915220   2  Class_Imbalance_Rate
# 5    0.894531  0.018219  0.962185  0.927126   2  Class_Imbalance_Rate
# 6    0.859406  0.015075  0.966592  0.909853   2  Class_Imbalance_Rate
# 7    0.865580  0.021804  0.950783  0.906183   2  Class_Imbalance_Rate
# 8    0.859406  0.017085  0.962306  0.907950   2  Class_Imbalance_Rate
# 9    0.879845  0.022358  0.953782  0.915323   2  Class_Imbalance_Rate
# 10   0.815195  0.005961  0.970660  0.886161   4  Class_Imbalance_Rate
# 11   0.810309  0.007940  0.960880  0.879195   4  Class_Imbalance_Rate
# 12   0.836257  0.009562  0.957589  0.892820   4  Class_Imbalance_Rate
# 13   0.816367  0.009005  0.957845  0.881466   4  Class_Imbalance_Rate
# 14   0.844720  0.012890  0.940092  0.889858   4  Class_Imbalance_Rate
# 15   0.807087  0.005522  0.973872  0.882670   4  Class_Imbalance_Rate
# 16   0.791667  0.010521  0.950000  0.863636   4  Class_Imbalance_Rate
# 17   0.815789  0.005982  0.971084  0.886689   4  Class_Imbalance_Rate
# 18   0.832000  0.005000  0.976526  0.898488   4  Class_Imbalance_Rate
# 19   0.833648  0.007103  0.969231  0.896341   4  Class_Imbalance_Rate
# 20   0.841772  0.005948  0.956835  0.895623   6  Class_Imbalance_Rate
# 21   0.787402  0.003676  0.973236  0.870511   6  Class_Imbalance_Rate
# 22   0.824762  0.005042  0.966518  0.890031   6  Class_Imbalance_Rate
# 23   0.829522  0.006293  0.954545  0.887653   6  Class_Imbalance_Rate
# 24   0.808853  0.003663  0.973366  0.883516   6  Class_Imbalance_Rate
# 25   0.793834  0.003355  0.976303  0.875664   6  Class_Imbalance_Rate
# 26   0.791252  0.004004  0.970732  0.871851   6  Class_Imbalance_Rate
# 27   0.835590  0.004693  0.968610  0.897196   6  Class_Imbalance_Rate
# 28   0.808300  0.005010  0.964623  0.879570   6  Class_Imbalance_Rate
# 29   0.775551  0.002666  0.979747  0.865772   6  Class_Imbalance_Rate
# ..        ...       ...       ...       ...  ..                   ...
# 370  0.757759  0.001347  0.967078  0.849718  20                   FOS
# 371  0.804917  0.002378  0.946445  0.869963  20              ensemble
# 372  0.793229  0.002210  0.949349  0.864295  20                   ROS
# 373  0.767029  0.001936  0.953885  0.850313  20                   RUS
# 374  0.764611  0.001452  0.964903  0.853159  20                   FOS
# 375  0.812576  0.002525  0.943820  0.873294  20              ensemble
# 376  0.781137  0.002462  0.943066  0.854497  20                   ROS
# 377  0.782749  0.002210  0.948705  0.857774  20                   RUS
# 378  0.766626  0.001494  0.964014  0.854064  20                   FOS
# 379  0.810560  0.002652  0.941039  0.870940  20              ensemble
# 380  0.794438  0.001915  0.955868  0.867709  20                   ROS
# 381  0.758565  0.001620  0.960694  0.847748  20                   RUS
# 382  0.749295  0.001494  0.963212  0.842893  20                   FOS
# 383  0.808142  0.002273  0.948888  0.872878  20              ensemble
# 384  0.792825  0.002357  0.946128  0.862719  20                   ROS
# 385  0.765014  0.001936  0.953769  0.849027  20                   RUS
# 386  0.760983  0.001494  0.963757  0.850450  20                   FOS
# 387  0.813382  0.002567  0.942991  0.873404  20              ensemble
# 388  0.799274  0.001873  0.957046  0.871074  20                   ROS
# 389  0.777509  0.001915  0.954950  0.857143  20                   RUS
# 390  0.763805  0.001136  0.972293  0.855530  20                   FOS
# 391  0.816203  0.002020  0.954738  0.880052  20              ensemble
# 392  0.793632  0.002420  0.944818  0.862651  20                   ROS
# 393  0.770254  0.002020  0.952167  0.851604  20                   RUS
# 394  0.747682  0.001115  0.972222  0.845295  20                   FOS
# 395  0.809754  0.002441  0.945412  0.872340  20              ensemble
# 396  0.797259  0.001873  0.956942  0.869833  20                   ROS
# 397  0.777912  0.002210  0.948403  0.854739  20                   RUS
# 398  0.759774  0.001452  0.964688  0.850056  20                   FOS
# 399  0.812576  0.002104  0.952741  0.877094  20              ensemble
#
# [500 rows x 6 columns]

# %%
fig, ax = plt.subplots(2,2, figsize=(20,8))
fig = fig1[fig1[4] == 2]
sns.boxplot(fig[5],fig[0],ax=ax[0][0])
ax[0][0].set_ylabel('True Positive Rate')

sns.boxplot(fig[5],fig[1],ax=ax[0][1])
ax[0][1].set_ylabel('False Positive Rate')

a=sns.boxplot(fig[5], fig[2],ax=ax[1][0])
a.set_ylabel('Precision')

a=sns.boxplot(fig[5], fig[3])
a.set_ylabel('F-Measure')
#class-imbalance =2
# Out:
# Text(0,0.5,'F-Measure')

# %%
fig, ax = plt.subplots(2,2, figsize=(20,8))
fig = fig1[fig1[4] == 10]
sns.boxplot(fig[5],fig[0],ax=ax[0][0])
ax[0][0].set_ylabel('True Positive Rate')

sns.boxplot(fig[5],fig[1],ax=ax[0][1])
ax[0][1].set_ylabel('False Positive Rate')

a=sns.boxplot(fig[5], fig[2],ax=ax[1][0])
a.set_ylabel('Precision')

a=sns.boxplot(fig[5], fig[3])
a.set_ylabel('F-Measure')
# Out:
# Text(0,0.5,'F-Measure')

# %%
fig, ax = plt.subplots(2,2, figsize=(20,8))

# TPR
fig = fig1[fig1[5] == "Class_Imbalance_Rate"]
fig = fig.groupby(4).mean()
fig[5] = fig.index

ax[0][0].plot(fig[5], fig[0], color="red", lw=1, ls='-', marker='o', markersize=4)

fig = fig1[fig1[5] == "ROS"]
fig = fig.groupby(4).mean()
fig[5] = fig.index

ax[0][0].plot(fig[5], fig[0], color="purple", lw=1, ls='-', marker='o', markersize=4)

fig = fig1[fig1[5] == "RUS"]
fig = fig.groupby(4).mean()
fig[5] = fig.index

ax[0][0].plot(fig[5], fig[0], color="green", lw=1, ls='-', marker='o', markersize=4)

fig = fig1[fig1[5] == "FOS"]
fig = fig.groupby(4).mean()
fig[5] = fig.index

ax[0][0].plot(fig[5], fig[0], color="black", lw=1, ls='-', marker='o', markersize=4)

fig = fig1[fig1[5] == "ensemble"]
fig = fig.groupby(4).mean()
fig[5] = fig.index

ax[0][0].plot(fig[5], fig[0], color="blue", lw=1, ls='-', marker='o', markersize=4)
ax[0][0].set_ylabel('True Positive Rate')
ax[0][0].set_xlabel('Class Imbalance Rate')

# FPR
fig = fig1[fig1[5] == "Class_Imbalance_Rate"]
fig = fig.groupby(4).mean()
fig[5] = fig.index

ax[0][1].plot(fig[5], fig[1], color="red", lw=1, ls='-', marker='o', markersize=4)

fig = fig1[fig1[5] == "ROS"]
fig = fig.groupby(4).mean()
fig[5] = fig.index

ax[0][1].plot(fig[5], fig[1], color="purple", lw=1, ls='-', marker='o', markersize=4)

fig = fig1[fig1[5] == "RUS"]
fig = fig.groupby(4).mean()
fig[5] = fig.index

ax[0][1].plot(fig[5], fig[1], color="green", lw=1, ls='-', marker='o', markersize=4)

fig = fig1[fig1[5] == "FOS"]
fig = fig.groupby(4).mean()
fig[5] = fig.index

ax[0][1].plot(fig[5], fig[1], color="black", lw=1, ls='-', marker='o', markersize=4)

fig = fig1[fig1[5] == "ensemble"]
fig = fig.groupby(4).mean()
fig[5] = fig.index

ax[0][1].plot(fig[5], fig[1], color="blue", lw=1, ls='-', marker='o', markersize=4)
ax[0][1].set_ylabel('False Positive Rate')
ax[0][1].set_xlabel('Class Imbalance Rate')

# Precision
fig = fig1[fig1[5] == "Class_Imbalance_Rate"]
fig = fig.groupby(4).mean()
fig[5] = fig.index

ax[1][0].plot(fig[5], fig[2], color="red", lw=1, ls='-', marker='o', markersize=4)

fig = fig1[fig1[5] == 'ROS']
fig = fig.groupby(4).mean()
fig[5] = fig.index

ax[1][0].plot(fig[5], fig[2], color="purple", lw=1, ls='-', marker='o', markersize=4)

fig = fig1[fig1[5] == 'RUS']
fig = fig.groupby(4).mean()
fig[5] = fig.index

ax[1][0].plot(fig[5], fig[2], color="green", lw=1, ls='-', marker='o', markersize=4)

fig = fig1[fig1[5] == "FOS"]
fig = fig.groupby(4).mean()
fig[5] = fig.index

ax[1][0].plot(fig[5], fig[2], color="black", lw=1, ls='-', marker='o', markersize=4)


fig = fig1[fig1[5] == "ensemble"]
fig = fig.groupby(4).mean()
fig[5] = fig.index

ax[1][0].plot(fig[5], fig[2], color="blue", lw=1, ls='-', marker='o', markersize=4)

ax[1][0].set_ylabel('Precision')
ax[1][0].set_xlabel('Class Imbalance Rate')

#F-measure
fig = fig1[fig1[5] == "Class_Imbalance_Rate"]
fig = fig.groupby(4).mean()
fig[5] = fig.index

ax[1][1].plot(fig[5], fig[3], color="red", lw=1, ls='-', marker='o', markersize=4)

fig = fig1[fig1[5] == 'ROS']
fig = fig.groupby(4).mean()
fig[5] = fig.index

ax[1][1].plot(fig[5], fig[3], color="purple", lw=1, ls='-', marker='o', markersize=4)

fig = fig1[fig1[5] == 'RUS']
fig = fig.groupby(4).mean()
fig[5] = fig.index

ax[1][1].plot(fig[5], fig[3], color="green", lw=1, ls='-', marker='o', markersize=4)

fig = fig1[fig1[5] == "FOS"]
fig = fig.groupby(4).mean()
fig[5] = fig.index

ax[1][1].plot(fig[5], fig[3], color="black", lw=1, ls='-', marker='o', markersize=4)


fig = fig1[fig1[5] == "ensemble"]
fig = fig.groupby(4).mean()
fig[5] = fig.index

ax[1][1].plot(fig[5], fig[3], color="blue", lw=1, ls='-', marker='o', markersize=4)

ax[1][1].set_ylabel('F-measure')
ax[1][1].set_xlabel('Class Imbalance Rate')
# Out:
# Text(0.5,0,'Class Imbalance Rate')

# %% [markdown]
# red= imbalnced,purple=ROS,green=RUS,black=FOS,blue=ENSEMBLE

# %% [markdown]
# THE END
